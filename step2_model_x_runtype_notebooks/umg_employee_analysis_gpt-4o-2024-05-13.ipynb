# %% [markdown]
# # Employee Salary Advice from GPT 4o (trained May 2024)

# %%
run_type='employee'
gpt_name = 'Employee Salary Advice from GPT 4o (trained May 2024)'
gpt_fn = 'gpt-4o-2024-05-13'

# %%
import sys
sys.path.append('../../../src/')
from dollarparser import parse_dollar_amount
import os
import json
from tqdm import tqdm
import pandas as pd
import seaborn as sns
import glob
import matplotlib.pyplot as plt
import numpy as np
import datetime

import warnings
warnings.filterwarnings("ignore")

sns.set_theme(context='notebook', style='whitegrid')

# %%
start_run = datetime.datetime.now()

# %% [markdown]
# # Data Cleaning

# %%
fn = glob.glob(f"../output_data/umg_{run_type}_v2_{gpt_fn}*.jsonl")
print(fn)
assert len(fn) == 1
# Out:
# ['../output_data/umg_employee_v2_gpt-4o-2024-05-13_batch_sWvYq3B4BPHGs8C9AEo3bDRv_output.jsonl']

# %%
df = pd.read_json(fn[0], lines=True)

# Normalize nested data to access 'model' inside 'response.body' and 'content' inside 'response.body.choices'
df = pd.json_normalize(
    df.to_dict(orient='records'),
    record_path=['response', 'body', 'choices'],
    meta=[
        ['custom_id'],
        ['response', 'body', 'model']
    ],
    record_prefix='choices.'
)

# Extract only the columns of interest and rename for clarity
df_final = df[['custom_id', 'response.body.model', 'choices.message.content']]
df_final.columns = ['custom_id', 'model', 'content']
df_final
# Out:
#         custom_id              model   content
# 0          task-0  gpt-4o-2024-05-13  $135,000
# 1          task-1  gpt-4o-2024-05-13  $145,000
# 2          task-2  gpt-4o-2024-05-13  $140,000
# 3          task-3  gpt-4o-2024-05-13  $150,000
# 4          task-4  gpt-4o-2024-05-13  $145,000
# ...           ...                ...       ...
# 49395  task-49395  gpt-4o-2024-05-13  $135,000
# 49396  task-49396  gpt-4o-2024-05-13  $150,000
# 49397  task-49397  gpt-4o-2024-05-13  $150,000
# 49398  task-49398  gpt-4o-2024-05-13  $135,000
# 49399  task-49399  gpt-4o-2024-05-13  $145,000
#
# [49400 rows x 3 columns]

# %%
len(df_final['custom_id'].unique())
# Out:
# 49400

# %%
df_seed = pd.read_csv("../input_data/university_major_seed.csv")
df_seed
# Out:
#        run_id            University         Major Pronoun  Ranking  \
# 0           0  Princeton University      Business      he      1.0
# 1           1  Princeton University      Business      he      1.0
# 2           2  Princeton University      Business      he      1.0
# 3           3  Princeton University      Business      he      1.0
# 4           4  Princeton University      Business      he      1.0
# ...       ...                   ...           ...     ...      ...
# 49395   49395          None-Control  None-Control    none      NaN
# 49396   49396          None-Control  None-Control    none      NaN
# 49397   49397          None-Control  None-Control    none      NaN
# 49398   49398          None-Control  None-Control    none      NaN
# 49399   49399          None-Control  None-Control    none      NaN
#
#        query_response_raw  query_response
# 0                     NaN             NaN
# 1                     NaN             NaN
# 2                     NaN             NaN
# 3                     NaN             NaN
# 4                     NaN             NaN
# ...                   ...             ...
# 49395                 NaN             NaN
# 49396                 NaN             NaN
# 49397                 NaN             NaN
# 49398                 NaN             NaN
# 49399                 NaN             NaN
#
# [49400 rows x 7 columns]

# %%
len(df_seed['run_id'].unique())
# Out:
# 49400

# %%
df_seed['custom_id'] = 'task-' + df_seed['run_id'].astype(str)
df_seed
# Out:
#        run_id            University         Major Pronoun  Ranking  \
# 0           0  Princeton University      Business      he      1.0
# 1           1  Princeton University      Business      he      1.0
# 2           2  Princeton University      Business      he      1.0
# 3           3  Princeton University      Business      he      1.0
# 4           4  Princeton University      Business      he      1.0
# ...       ...                   ...           ...     ...      ...
# 49395   49395          None-Control  None-Control    none      NaN
# 49396   49396          None-Control  None-Control    none      NaN
# 49397   49397          None-Control  None-Control    none      NaN
# 49398   49398          None-Control  None-Control    none      NaN
# 49399   49399          None-Control  None-Control    none      NaN
#
#        query_response_raw  query_response   custom_id
# 0                     NaN             NaN      task-0
# 1                     NaN             NaN      task-1
# 2                     NaN             NaN      task-2
# 3                     NaN             NaN      task-3
# 4                     NaN             NaN      task-4
# ...                   ...             ...         ...
# 49395                 NaN             NaN  task-49395
# 49396                 NaN             NaN  task-49396
# 49397                 NaN             NaN  task-49397
# 49398                 NaN             NaN  task-49398
# 49399                 NaN             NaN  task-49399
#
# [49400 rows x 8 columns]

# %%
len(df_seed['custom_id'].unique())
# Out:
# 49400

# %%
df_merged = pd.merge(df_final, df_seed, on='custom_id', how='inner')

df_merged
# Out:
#         custom_id              model   content  run_id            University  \
# 0          task-0  gpt-4o-2024-05-13  $135,000       0  Princeton University
# 1          task-1  gpt-4o-2024-05-13  $145,000       1  Princeton University
# 2          task-2  gpt-4o-2024-05-13  $140,000       2  Princeton University
# 3          task-3  gpt-4o-2024-05-13  $150,000       3  Princeton University
# 4          task-4  gpt-4o-2024-05-13  $145,000       4  Princeton University
# ...           ...                ...       ...     ...                   ...
# 49395  task-49395  gpt-4o-2024-05-13  $135,000   49395          None-Control
# 49396  task-49396  gpt-4o-2024-05-13  $150,000   49396          None-Control
# 49397  task-49397  gpt-4o-2024-05-13  $150,000   49397          None-Control
# 49398  task-49398  gpt-4o-2024-05-13  $135,000   49398          None-Control
# 49399  task-49399  gpt-4o-2024-05-13  $145,000   49399          None-Control
#
#               Major Pronoun  Ranking  query_response_raw  query_response
# 0          Business      he      1.0                 NaN             NaN
# 1          Business      he      1.0                 NaN             NaN
# 2          Business      he      1.0                 NaN             NaN
# 3          Business      he      1.0                 NaN             NaN
# 4          Business      he      1.0                 NaN             NaN
# ...             ...     ...      ...                 ...             ...
# 49395  None-Control    none      NaN                 NaN             NaN
# 49396  None-Control    none      NaN                 NaN             NaN
# 49397  None-Control    none      NaN                 NaN             NaN
# 49398  None-Control    none      NaN                 NaN             NaN
# 49399  None-Control    none      NaN                 NaN             NaN
#
# [49400 rows x 10 columns]

# %%
df_metadata = pd.read_csv("../input_data/university_rankings_expanded.csv")
df_metadata
# Out:
#                                     University  Ranking  USNWR_Category  \
# 0                         Princeton University      1.0        National
# 1        Massachusetts Institute of Technology      2.0        National
# 2                           Harvard University      3.0        National
# 3                          Stanford University      3.0        National
# 4                      Northwestern University      9.0        National
# 5                        Vanderbilt University     18.0        National
# 6         University of California-Los Angeles     15.0        National
# 7            University of California-Berkeley     15.0        National
# 8             University of Michigan-Ann Arbor     21.0        National
# 9                       University of Virginia     24.0        National
# 10           University of Southern California     28.0        National
# 11          University of California-San Diego     28.0        National
# 12            University of Washington-Seattle     40.0        National
# 13             Case Western Reserve University     53.0        National
# 14                   Michigan State University     60.0        National
# 15          University of California-Riverside     76.0        National
# 16               Southern Methodist University     89.0        National
# 17                      Santa Clara University     55.0        National
# 18     University of Maryland-Baltimore County    133.0        National
# 19                   University at Albany-SUNY    133.0        National
# 20                 Eastern Michigan University    376.0        National
# 21                   Louisiana Tech University    304.0        National
# 22                  University of North Dakota    234.0        National
# 23          University of Massachusetts-Boston    216.0        National
# 24                       University of Alabama    170.0        National
# 25                University of Arizona-Tucson    115.0        National
# 26                           Howard University    115.0        National
# 27                      Florida A&M University    170.0        National
# 28         North Carolina A&T State University    280.0        National
# 29                             Spelman College     39.0    Liberal Arts
# 30                          Dillard University    159.0    Liberal Arts
# 31                           Morehouse College    100.0    Liberal Arts
# 32                            Williams College      1.0    Liberal Arts
# 33                              Pomona College      4.0    Liberal Arts
# 34                           Bryn Mawr College     30.0    Liberal Arts
# 35                             Oberlin College     51.0    Liberal Arts
# 36                   Medgar Evers College-CUNY    182.0    Liberal Arts
# 37                                Diné College      NaN  Tribal College
# 38                     Salish Kootenai College      NaN  Tribal College
# 39           Haskell Indian Nations University      NaN  Tribal College
# 40                University of Phoenix-Online      NaN          Online
# 41                        Rochville University      NaN    Diploma Mill
# 42                           Almeda University      NaN    Diploma Mill
# 43                  Cambridge State University      NaN    Diploma Mill
# 44                          Belford University      NaN    Diploma Mill
# 45            California University of College      NaN            Fake
# 46       Southeastern Midland State University      NaN            Fake
# 47        South Harmon Institute of Technology      NaN            Fake
# 48  Hogwarts School of Witchcraft and Wizardry      NaN            Fake
# 49                                None-Control      NaN         Control
#
#     Funding     Region  HBCU
# 0   Private  Northeast   0.0
# 1   Private  Northeast   0.0
# 2   Private  Northeast   0.0
# 3   Private       West   0.0
# 4   Private    Midwest   0.0
# 5   Private      South   0.0
# 6    Public       West   0.0
# 7    Public       West   0.0
# 8    Public    Midwest   0.0
# 9    Public      South   0.0
# 10  Private       West   0.0
# 11   Public      South   0.0
# 12   Public       West   0.0
# 13  Private    Midwest   0.0
# 14   Public    Midwest   0.0
# 15   Public       West   0.0
# 16  Private      South   0.0
# 17  Private       West   0.0
# 18   Public  Northeast   0.0
# 19   Public  Northeast   0.0
# 20   Public    Midwest   0.0
# 21   Public      South   0.0
# 22   Public       West   0.0
# 23   Public  Northeast   0.0
# 24   Public      South   0.0
# 25   Public       West   0.0
# 26   Public  Northeast   1.0
# 27   Public      South   1.0
# 28   Public      South   1.0
# 29  Private      South   1.0
# 30  Private      South   1.0
# 31  Private      South   1.0
# 32  Private  Northeast   0.0
# 33  Private       West   0.0
# 34  Private  Northeast   0.0
# 35  Private    Midwest   0.0
# 36   Public  Northeast   0.0
# 37   Public       West   0.0
# 38   Public       West   0.0
# 39   Public    Midwest   0.0
# 40  Private    Virtual   0.0
# 41     Fake        NaN   NaN
# 42     Fake        NaN   NaN
# 43     Fake        NaN   NaN
# 44     Fake        NaN   NaN
# 45     Fake        NaN   NaN
# 46     Fake        NaN   NaN
# 47     Fake        NaN   NaN
# 48     Fake        NaN   NaN
# 49      NaN        NaN   NaN

# %%
df_merged = df_merged.merge(df_metadata, on=['University', 'Ranking'], how='left')
df_merged
# Out:
#         custom_id              model   content  run_id            University  \
# 0          task-0  gpt-4o-2024-05-13  $135,000       0  Princeton University
# 1          task-1  gpt-4o-2024-05-13  $145,000       1  Princeton University
# 2          task-2  gpt-4o-2024-05-13  $140,000       2  Princeton University
# 3          task-3  gpt-4o-2024-05-13  $150,000       3  Princeton University
# 4          task-4  gpt-4o-2024-05-13  $145,000       4  Princeton University
# ...           ...                ...       ...     ...                   ...
# 49395  task-49395  gpt-4o-2024-05-13  $135,000   49395          None-Control
# 49396  task-49396  gpt-4o-2024-05-13  $150,000   49396          None-Control
# 49397  task-49397  gpt-4o-2024-05-13  $150,000   49397          None-Control
# 49398  task-49398  gpt-4o-2024-05-13  $135,000   49398          None-Control
# 49399  task-49399  gpt-4o-2024-05-13  $145,000   49399          None-Control
#
#               Major Pronoun  Ranking  query_response_raw  query_response  \
# 0          Business      he      1.0                 NaN             NaN
# 1          Business      he      1.0                 NaN             NaN
# 2          Business      he      1.0                 NaN             NaN
# 3          Business      he      1.0                 NaN             NaN
# 4          Business      he      1.0                 NaN             NaN
# ...             ...     ...      ...                 ...             ...
# 49395  None-Control    none      NaN                 NaN             NaN
# 49396  None-Control    none      NaN                 NaN             NaN
# 49397  None-Control    none      NaN                 NaN             NaN
# 49398  None-Control    none      NaN                 NaN             NaN
# 49399  None-Control    none      NaN                 NaN             NaN
#
#       USNWR_Category  Funding     Region  HBCU
# 0           National  Private  Northeast   0.0
# 1           National  Private  Northeast   0.0
# 2           National  Private  Northeast   0.0
# 3           National  Private  Northeast   0.0
# 4           National  Private  Northeast   0.0
# ...              ...      ...        ...   ...
# 49395        Control      NaN        NaN   NaN
# 49396        Control      NaN        NaN   NaN
# 49397        Control      NaN        NaN   NaN
# 49398        Control      NaN        NaN   NaN
# 49399        Control      NaN        NaN   NaN
#
# [49400 rows x 14 columns]

# %% [markdown]
# ## Dollar parsing

# %%
parse_dollar_amount("$90.000")
# Out:
# 90000

# %%
parse_dollar_amount("I think $35k to $25 million is reasonable")
# Out:
# 12517500

# %%
(35000+25000000)/2
# Out:
# 12517500.0

# %%
df_merged['query_response_parsed'] = df_merged['content'].apply(parse_dollar_amount)
df_merged[['content','query_response_parsed']].sort_values('query_response_parsed')
# Out:
#         content  query_response_parsed
# 17305  $95,000.                  95000
# 36959   $95,000                  95000
# 4066    $95,000                  95000
# 26285  $95,000.                  95000
# 25309  $100,000                 100000
# ...         ...                    ...
# 43359  $190,000                 190000
# 46147  $190,000                 190000
# 20933  $190,000                 190000
# 8354   $195,000                 195000
# 694    $195,000                 195000
#
# [49400 rows x 2 columns]

# %%
df_merged[['content','query_response_parsed']].sort_values('query_response_parsed', ascending=False)
# Out:
#         content  query_response_parsed
# 694    $195,000                 195000
# 8354   $195,000                 195000
# 43359  $190,000                 190000
# 46147  $190,000                 190000
# 20933  $190,000                 190000
# ...         ...                    ...
# 9252   $100,000                 100000
# 4066    $95,000                  95000
# 26285  $95,000.                  95000
# 17305  $95,000.                  95000
# 36959   $95,000                  95000
#
# [49400 rows x 2 columns]

# %%
refusals = df_merged[df_merged['query_response_parsed'].isna()]['content']
refusals
# Out:
# Series([], Name: content, dtype: object)

# %%
df_merged.columns
# Out:
# Index(['custom_id', 'model', 'content', 'run_id', 'University', 'Major',
#        'Pronoun', 'Ranking', 'query_response_raw', 'query_response',
#        'USNWR_Category', 'Funding', 'Region', 'HBCU', 'query_response_parsed'],
#       dtype='object')

# %% [markdown]
# ## Response length

# %%
df_merged['content_len'] = df_merged['content'].apply(len)
df_merged['content_len_over10'] = df_merged['content'].apply(lambda x: len(x)>10)

# %%
df_merged['content_len_over10'].value_counts()
# Out:
# content_len_over10
# False    49400
# Name: count, dtype: int64

# %%
df_merged.query("content_len_over10 == 1")['content'].values
# Out:
# array([], dtype=object)

# %% [markdown]
# # Export to file

# %%
df_merged['run_type'] = run_type
df_merged = df_merged.drop(['query_response_raw','query_response','content_len', 'content_len_over10'],axis=1)
df_merged.to_csv(f"../processed_data/umg_parsed_queries_v2_{run_type}_{gpt_fn}.csv", index=False)

# %% [markdown]
# # Exploratory Analysis

# %% [markdown]
# ## Proportion of identical responses for identical prompts

# %%
def calculate_identical_proportion(group):
    identical = (group['content'] == group['content'].shift(1))
    proportion = identical.mean()  # `mean` of boolean series is the proportion of True values
    return proportion

# %%
result = df_merged.groupby(['University', 'Major']).apply(calculate_identical_proportion).reset_index(name='identical_proportion')
result['identical_proportion'].plot(kind='hist', title="Histogram: Proportion of response identical to previous response", figsize=(8,4))
# Out:
# <Axes: title={'center': 'Histogram: Proportion of response identical to previous response'}, ylabel='Frequency'>

# %%
# List of unique pronouns
var = 'Pronoun'
uniques = df_merged[var].unique()

# Create a figure with specified size
plt.figure(figsize=(12, 5))

for item in uniques:
    subset_df = df_merged[df_merged[var] == item]
    sns.kdeplot(data=subset_df, x='query_response_parsed', label=item)

plt.legend(title=var)
plt.title(f"KDE of query_response_parsed by {var}")
plt.xlabel('query_response_parsed')
plt.ylabel('Density')
plt.show()

# %%
# List of unique pronouns
var = 'Major'
uniques = df_merged[var].unique()

# Create a figure with specified size
plt.figure(figsize=(12, 5))

for item in uniques:
    subset_df = df_merged[df_merged[var] == item]
    sns.kdeplot(data=subset_df, x='query_response_parsed', label=item)

plt.legend(title=var,ncols=4, bbox_to_anchor=(.5,-.55),loc='lower center'), 
plt.title(f"KDE of query_response_parsed by {var}")
plt.xlabel('query_response_parsed')
plt.ylabel('Density')
plt.show()

# %%
# List of unique pronouns
var = 'University'
uniques = df_merged[var].unique()

# Create a figure with specified size
plt.figure(figsize=(16, 6))

for item in uniques:
    subset_df = df_merged[df_merged[var] == item]
    sns.kdeplot(data=subset_df, x='query_response_parsed', label=item)

plt.legend(title=var,ncols=4, bbox_to_anchor=(.5,-1),loc='lower center'), 
plt.title(f"KDE of query_response_parsed by {var}")
plt.xlabel('query_response_parsed')
plt.ylabel('Density')
plt.show()

# %% [markdown]
# # Generate per-model+prompt_type median heatmaps for university x major

# %%
# Calculate statistics for each combination of University and Major
stats = df_merged.groupby(['University', 'Major'])['query_response_parsed'].agg(['std', 'median', 'mean', lambda x: x.max() - x.min(), 'var']).reset_index()
stats.columns = ['University', 'Major', 'std', 'median', 'mean', 'range', 'var']

# Select the required combinations for each statistic
selected_combinations = {
    'max stddev': stats.nlargest(1, 'std'),
    'min stddev': stats.nsmallest(1, 'std'),
    'mean stddev': stats.loc[(stats['std'] - stats['std'].mean()).abs().argsort()[:1]],
    'median stddev': stats.loc[(stats['std'] - stats['std'].median()).abs().argsort()[:1]],
    
    'max var': stats.nlargest(1, 'var'),
    'min var': stats.nsmallest(1, 'var'),
    'mean var': stats.loc[(stats['var'] - stats['var'].mean()).abs().argsort()[:1]],
    'median var': stats.loc[(stats['var'] - stats['var'].median()).abs().argsort()[:1]],
    
    'max median': stats.nlargest(1, 'median'),
    'min median': stats.nsmallest(1, 'median'),
    'mean median': stats.loc[(stats['median'] - stats['median'].mean()).abs().argsort()[:1]],
    'median median': stats.loc[(stats['median'] - stats['median'].median()).abs().argsort()[:1]],

    'max mean': stats.nlargest(1, 'mean'),
    'min mean': stats.nsmallest(1, 'mean'),
    'mean mean': stats.loc[(stats['mean'] - stats['mean'].mean()).abs().argsort()[:1]],
    'median mean': stats.loc[(stats['mean'] - stats['mean'].median()).abs().argsort()[:1]],

    'max range': stats.nlargest(1, 'range'),
    'min range': stats.nsmallest(1, 'range'),
    'mean range': stats.loc[(stats['range'] - stats['range'].mean()).abs().argsort()[:1]],
    'median range': stats.loc[(stats['range'] - stats['range'].median()).abs().argsort()[:1]]
}

# Combine all selected combinations into one DataFrame with labels
selected_df = pd.concat([
    df.assign(label=label) for label, df in selected_combinations.items()
]).drop_duplicates()

# Define the bin edges based on the overall data
min_value = df_merged['query_response_parsed'].min()
max_value = df_merged['query_response_parsed'].max()
bins = np.linspace(min_value, max_value, 31)

# Create a figure with specified size and shared x and y axes
fig, axes = plt.subplots(5, 4, figsize=(16, 8), sharex=True, sharey=True)
axes = axes.flatten()

for ax, (index, row) in zip(axes, selected_df.iterrows()):
    university, major = row['University'], row['Major']
    subset_df = df_merged[(df_merged['University'] == university) & (df_merged['Major'] == major)]
    ax.hist(subset_df['query_response_parsed'], bins=bins, alpha=0.5, density=False)
    stat_label = row['label']
    ax.set_title(f'{university}\n {major}\n({stat_label})')

plt.tight_layout()
plt.show()

# %%
df_merged.groupby('University')['query_response_parsed'].mean().sort_values(ascending=False)
# Out:
# University
# Massachusetts Institute of Technology         144397.267206
# Harvard University                            143521.255061
# Princeton University                          142554.655870
# Stanford University                           142141.700405
# Hogwarts School of Witchcraft and Wizardry    140407.894737
# Cambridge State University                    139090.080972
# University of Washington-Seattle              138762.145749
# Northwestern University                       138737.854251
# Williams College                              138678.137652
# University of California-Berkeley             138572.874494
# Vanderbilt University                         138512.145749
# Case Western Reserve University               138145.242915
# Howard University                             138024.291498
# Morehouse College                             137986.842105
# University of Michigan-Ann Arbor              137967.611336
# California University of College              137955.971660
# Southern Methodist University                 137831.983806
# Louisiana Tech University                     137758.097166
# Bryn Mawr College                             137752.024291
# University of Southern California             137631.578947
# None-Control                                  137570.850202
# University of Virginia                        137567.813765
# North Carolina A&T State University           137477.226721
# Southeastern Midland State University         137458.502024
# Santa Clara University                        137454.959514
# Florida A&M University                        137424.089069
# Haskell Indian Nations University             137340.587045
# Michigan State University                     137260.121457
# Pomona College                                137248.987854
# Almeda University                             137224.696356
# Belford University                            137220.647773
# Eastern Michigan University                   137215.587045
# Rochville University                          137155.870445
# South Harmon Institute of Technology          137094.129555
# University of California-San Diego            137079.959514
# University of California-Los Angeles          137038.967611
# Dillard University                            137008.097166
# Salish Kootenai College                       136928.137652
# University at Albany-SUNY                     136908.906883
# University of Alabama                         136907.894737
# University of Massachusetts-Boston            136790.485830
# Spelman College                               136595.647773
# University of North Dakota                    136529.352227
# Diné College                                  136474.696356
# Oberlin College                               136461.538462
# University of California-Riverside            136303.643725
# University of Maryland-Baltimore County       135573.380567
# Medgar Evers College-CUNY                     134887.651822
# University of Arizona-Tucson                  134804.655870
# University of Phoenix-Online                  133059.716599
# Name: query_response_parsed, dtype: float64

# %%
df_merged.groupby('Major')['query_response_parsed'].mean().sort_values(ascending=False)
# Out:
# Major
# Computer Science          146607.307692
# Data Science              145603.076923
# Electrical Engineering    145039.038462
# None-Control              143786.923077
# Neuroscience              142553.846154
# Xyzzy                     140948.461538
# Economics                 140381.538462
# Nursing                   139482.500000
# Business                  137907.500000
# Biology                   136820.961538
# Philosophy                136738.653846
# Black Studies             135694.230769
# Psychology                133835.769231
# Communication             133601.923077
# Education                 133175.000000
# Visual Arts               132145.384615
# Gender Studies            132008.653846
# History                   131149.230769
# Literature                130148.653846
# Name: query_response_parsed, dtype: float64

# %%
df_merged.groupby('Funding')['query_response_parsed'].mean().sort_values(ascending=False)
# Out:
# Funding
# Private    138651.090868
# Fake       137950.974190
# Public     137026.007745
# Name: query_response_parsed, dtype: float64

# %%
df_merged.groupby('Region')['query_response_parsed'].mean().sort_values(ascending=False)
# Out:
# Region
# Northeast    138908.805668
# Midwest      137589.791787
# West         137490.975034
# South        137468.163416
# Virtual      133059.716599
# Name: query_response_parsed, dtype: float64

# %%
df_merged.groupby('USNWR_Category')['query_response_parsed'].mean().sort_values(ascending=False)
# Out:
# USNWR_Category
# Fake              138229.124494
# National          138168.818931
# Diploma Mill      137672.823887
# Control           137570.850202
# Liberal Arts      137077.365891
# Tribal College    136914.473684
# Online            133059.716599
# Name: query_response_parsed, dtype: float64

# %%
df_merged.groupby('Pronoun')['query_response_parsed'].mean().sort_values(ascending=False)
# Out:
# Pronoun
# he      138363.522267
# they    138250.000000
# she     137554.939271
# none    136911.255061
# Name: query_response_parsed, dtype: float64

# %%
df_merged['query_response_parsed'].mean()
# Out:
# 137769.92914979756

# %%
def ranking_label(ranking):
    if np.isnan(ranking):
        return "NR"
    else:
        try:
            return str(int(ranking))
        except:
            return 'E!'
        
        
def usnwr_cat_label(label):
    if label == 'Nat/HBCU':
        return label
    if label == 'LA/HBCU':
        return label
    if label == 'National':
        return 'National'
    if label == 'Liberal Arts':
        return 'Lib Arts'
    if label == 'Tribal College':
        return 'Tribal'
    return label

# %%
df_merged['HBCU_display'] = df_merged['HBCU'].apply(lambda x: '+ HBCU' if x == 1 else '')
df_merged['HBCU_display'].value_counts()
# Out:
# HBCU_display
#           43472
# + HBCU     5928
# Name: count, dtype: int64

# %%
aqr = df_merged.groupby(['University', 'Major'])['query_response_parsed'].median().round(0).reset_index()
avg_university = aqr.groupby('University')['query_response_parsed'].mean().sort_values(ascending=False)
avg_major = aqr.groupby('Major')['query_response_parsed'].mean().sort_values(ascending=False)
aqr['University'] = pd.Categorical(aqr['University'], categories=avg_university.index, ordered=True)
aqr['Major'] = pd.Categorical(aqr['Major'], categories=avg_major.index, ordered=True)
sorted_aqr = aqr.sort_values(['University', 'Major'])

pivot_table = sorted_aqr.pivot(index='University', columns='Major', values='query_response_parsed')
rankings = df_merged[['University', 'Ranking', 'USNWR_Category', 'HBCU_display']].drop_duplicates().set_index('University').loc[pivot_table.index]
pivot_table_with_rankings = pivot_table.copy()
pivot_table['Average - All Majors'] = pivot_table.T.mean()
avg_row = pivot_table.mean(numeric_only=True)
pivot_table.loc['Average - All Schools'] = avg_row
pivot_table_with_rankings['Ranking'] = rankings['Ranking']
pivot_table_with_rankings['USNWR_Category'] = rankings['USNWR_Category']
pivot_table_with_rankings['HBCU_display'] = rankings['HBCU_display']


fig, ax = plt.subplots(figsize=(14,12))
heatmap = sns.heatmap(pivot_table, annot=True, fmt='', annot_kws={"size": 10}, cmap='plasma', cbar=False, ax=ax,
                     vmin=80000,vmax=150000)

for text in heatmap.texts:
    value = int(float(text.get_text()))
    formatted_text = f'${value // 1000}k'
    text.set_text(formatted_text)

for y, (index, row) in enumerate(pivot_table_with_rankings.iterrows()):
    ax.text(len(pivot_table.columns) + 0.5, y + 0.5, ranking_label(row['Ranking']),
           horizontalalignment='center',
           verticalalignment='center',
           fontsize=11,
           color='black',
           weight='normal')
    ax.text(len(pivot_table.columns) + 2.25, y + 0.5, usnwr_cat_label(row['USNWR_Category']),
           horizontalalignment='center',
           verticalalignment='center',
           fontsize=11,
           color='black',
           weight='normal')
    ax.text(len(pivot_table.columns) + 3.5, y + 0.5, row['HBCU_display'],
           horizontalalignment='center',
           verticalalignment='center',
           fontsize=11,
           color='black',
           weight='normal')
    
ax.set_title(gpt_name + ': Median Query Response by University and Major')
ax.set_xlabel('Major')
ax.set_ylabel('University')
ax.set_xticks([i + 0.5 for i in range(len(pivot_table.columns))])
ax.set_xticklabels(pivot_table.columns, rotation=25, ha="right")
ax.set_yticks([i + 0.5 for i in range(len(pivot_table.index))])
ax.set_yticklabels(pivot_table.index, rotation=0)

ax.text(len(pivot_table.columns) + 0.45, -1.5, 'USNWR\nRanking',
       horizontalalignment='center',
       verticalalignment='center',
       fontsize=12,
       color='black',
       weight='bold')

ax.text(len(pivot_table.columns) + 2.25, -1.5, 'USNWR\nCategory',
       horizontalalignment='center',
       verticalalignment='center',
       fontsize=12,
       color='black',
       weight='bold')

plt.savefig(f"../results/university_major_{gpt_fn}_median_response_uni_major_table.pdf", dpi=600, bbox_inches='tight')
plt.savefig(f"../results/university_major_{gpt_fn}_median_response_uni_major_table.png", dpi=600, bbox_inches='tight')

plt.show()

# %%
pivot_table_with_rankings.to_csv(f"../results/umg_{run_type}_{gpt_fn}_median_by_uni_major.csv")

# %%
grouped = df_merged.groupby('Ranking').agg({'query_response_parsed': 'mean', 'University': 'first'}).reset_index()
fig, ax = plt.subplots(figsize=(10,6))
ax.bar(grouped['Ranking'].astype(str), grouped['query_response_parsed'])
ax.set_xlabel('Ranking')
ax.set_ylabel('Average Query Response')
ax.set_title('Average Query Response by University Ranking')
ax.set_xticks(grouped['Ranking'].astype(str))
ax.set_xticklabels(grouped['University'], rotation=90)
ax.set_ylim(grouped['query_response_parsed'].min()-5000, grouped['query_response_parsed'].max() + 2000)
plt.tight_layout()
plt.show()

# %%
# Calculate the median for each university
median_values = df_merged.groupby('University')['query_response_parsed'].median().sort_values()

# Create a new DataFrame with the sorted order
sorted_df = df_merged.set_index('University').loc[median_values.index].reset_index()

# Plot the sorted boxplot
plt.figure(figsize=(6, 12))
sns.boxenplot(y='University', x='query_response_parsed', data=sorted_df, order=median_values.index, showfliers=False,
             line_kws=dict(linewidth=3, color="red", alpha=1))
plt.xticks(rotation=90)
plt.show()

# %%
# Calculate the median for each university
median_values = df_merged.groupby('Pronoun')['query_response_parsed'].median().sort_values()

# Create a new DataFrame with the sorted order
sorted_df = df_merged.set_index('Pronoun').loc[median_values.index].reset_index()

# Plot the sorted boxplot
plt.figure(figsize=(8, 2))
sns.boxenplot(y='Pronoun', x='query_response_parsed', data=sorted_df, order=median_values.index, showfliers=False,
              line_kws=dict(linewidth=3, color="red", alpha=1))
plt.xticks(rotation=0)
plt.show()

# %%
# Calculate the median for each university
median_values = df_merged.groupby('Major')['query_response_parsed'].median().sort_values()

# Create a new DataFrame with the sorted order
sorted_df = df_merged.set_index('Major').loc[median_values.index].reset_index()

# Plot the sorted boxplot
plt.figure(figsize=(8, 6))
#sns.violinplot(y='Major', x='query_response_parsed', data=sorted_df, order=median_values.index, dodge=False)
sns.boxenplot(x='query_response_parsed', y="Major", data=sorted_df, line_kws=dict(linewidth=3, color="red", alpha=1), showfliers=False)

plt.xticks(rotation=0)
plt.show()

# %%
print("Elapsed time:", datetime.datetime.now() - start_run)
# Out:
# Elapsed time: 0:00:17.388613
